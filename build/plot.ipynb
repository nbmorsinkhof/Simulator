# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.genfromtxt("data_log", delimiter=",")
data2 = np.genfromtxt("data_log2", delimiter=",")


data = data[:, :-1]
data2= data2[:, :-1]

c0 = data[:, 0]
c1 = data[:, 1]
c2 = data[:, 2]
c3 = data[:, 3]
c4 = data[:, 4]
c5 = data[:, 5]
c6 = data[:, 6]
c7 = data[:, 7]
c8 = data[:, 8]


c3_2 = data2[:, 3]

# %%
plt.plot(c3)
plt.plot(c3_2)
plt.grid()

# %%
plt.plot(c2)
plt.plot(c4)

# %%
plt.plot(c8)
